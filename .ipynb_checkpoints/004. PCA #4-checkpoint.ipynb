# %%
import tensorflow.keras as keras
import numpy as np

# generating examples (samples)
x = np.array([0, 1, 2, 3, 4])
y = x*2 + 1

# generating neural network modeling
model = keras.models.Sequential()
model.add(keras.layers.Dense(1, input_shape=(1,)))
model.compile('SGD', 'mse')

# before learning
print('Before Learning:')
print('Targets: ', y[2:])
print('Predictions: ', model.predict(x[2:]).flatten())
print(model.get_weights())

# training with two samples
model.fit(x[:2], y[:2], epochs=1000, verbose=0)
# model.fit(np.array([x[2]]), np.array([y[2]]), epochs=2000, verbose=0)


# # after learning
# print('After Learning:')
# print('Targets: ', y[2:])
# print('Predictions: ', model.predict(x[2:]).flatten())
# print(model.get_weights())
# Out:
# Before Learning:
# Targets:  [5 7 9]
# 1/1 [==============================] - 0s 26ms/step
# Predictions:  [2.798598 4.197897 5.597196]
# [array([[1.399299]], dtype=float32), array([0.], dtype=float32)]
# 2023-03-26 15:00:44.385439: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-26 15:00:44.643979: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-26 15:00:44.869583: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1658ede60
# 2023-03-26 15:00:44.869613: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1658ede60
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 20
#      17 print(model.get_weights())
#      19 # training with two samples
# ---> 20 model.fit(x[:2], y[:2], epochs=1000, verbose=0)
#      21 # model.fit(np.array([x[2]]), np.array([y[2]]), epochs=2000, verbose=0)
#      22
#      23
#    (...)
#      27 # print('Predictions: ', model.predict(x[2:]).flatten())
#      28 # print(model.get_weights())
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node 'StatefulPartitionedCall_1' defined at (most recent call last):
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/hsyoon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/v9/bwnxmmgs13zd3yg44zhmyl5r0000gn/T/ipykernel_20757/920807060.py", line 20, in <module>
#       model.fit(x[:2], y[:2], epochs=1000, verbose=0)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 527, in minimize
#       self.apply_gradients(grads_and_vars)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1140, in apply_gradients
#       return super().apply_gradients(grads_and_vars, name=name)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 634, in apply_gradients
#       iteration = self._internal_apply_gradients(grads_and_vars)
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1166, in _internal_apply_gradients
#       return tf.__internal__.distribute.interim.maybe_merge_call(
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1216, in _distributed_apply_gradients_fn
#       distribution.extended.update(
#     File "/opt/homebrew/Caskroom/miniconda/base/envs/tf/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1211, in apply_grad_to_update_var
#       return self._update_step_xla(grad, var, id(self._var_key(var)))
# Node: 'StatefulPartitionedCall_1'
# could not find registered platform with id: 0x1658ede60
# 	 [[{{node StatefulPartitionedCall_1}}]] [Op:__inference_train_function_660]
